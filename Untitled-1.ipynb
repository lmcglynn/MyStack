# %%
import pandas as pd
import numpy as np

df = pd.read_excel('JSTdatasetR6.xlsx')
#df.groupby('year')
#df.first

data2020 = df.groupby(['year']).get_group(2020)
# Out:
# /var/folders/0s/0yq8vr3x7v7dppjl4f_k7w440000gn/T/ipykernel_54427/1415873841.py:8: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data2020 = df.groupby(['year']).get_group(2020)

# %%
df.insert(1, 'inflation', df['cpi'].pct_change())
df
# Out:
# /var/folders/0s/0yq8vr3x7v7dppjl4f_k7w440000gn/T/ipykernel_54427/3061264919.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df.insert(1, 'inflation', df['cpi'].pct_change())
#       year  inflation    country  iso  ifs            pop       rgdpmad  \
# 0     1870        NaN  Australia  AUS  193    1775.000000   3273.239437
# 1     1871  -0.015384  Australia  AUS  193    1675.000000   3298.507463
# 2     1872  -0.046875  Australia  AUS  193    1722.000000   3553.426249
# 3     1873   0.000000  Australia  AUS  193    1769.000000   3823.629169
# 4     1874   0.049180  Australia  AUS  193    1822.000000   3834.796926
# ...    ...        ...        ...  ...  ...            ...           ...
# 2713  2016   0.012898        USA  USA  111  322701.246359  33012.767871
# ...

# %%
df.groupby('country')[['unemp','inflation']].corr()
# Out:
#                           unemp  inflation
# country
# Australia   unemp      1.000000  -0.308970
#             inflation -0.308970   1.000000
# Belgium     unemp      1.000000  -0.243626
#             inflation -0.243626   1.000000
# Canada      unemp      1.000000  -0.311798
#             inflation -0.311798   1.000000
# Denmark     unemp      1.000000   0.089910
#             inflation  0.089910   1.000000
# Finland     unemp      1.000000  -0.317721
#             inflation -0.317721   1.000000
# France      unemp      1.000000  -0.372163
#             inflation -0.372163   1.000000
# Germany     unemp      1.000000  -0.001005
#             inflation -0.001005   1.000000
# Ireland     unemp      1.000000  -0.044334
#             inflation -0.044334   1.000000
# Italy       unemp      1.000000  -0.020651
#             inflation -0.020651   1.000000
# Japan       unemp      1.000000  -0.414206
#             inflation -0.414206   1.000000
# Netherlands unemp      1.000000  -0.104678
# ...
